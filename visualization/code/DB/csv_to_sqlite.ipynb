# %%
import sqlite3
import pandas as pd

# %% [markdown]
# # DB 생성 및 연결

# %%
# SQLite 데이터베이스 파일 생성
conn = sqlite3.connect('ASAC_MAP.db')
cursor = conn.cursor()

# %%
# csv to sqlite 변환 함수

def csv_to_sqlite(csv_file, db_file, table_name, chunk_size=1000):
    try:
        # SQLite 데이터베이스 파일 연결
        conn = sqlite3.connect(db_file)
        
        # CSV 파일을 청크 단위로 읽어 SQLite로 변환
        for chunk in pd.read_csv(csv_file, chunksize=chunk_size):  # 여기에서 괄호 ()를 반드시 사용해야 합니다.
            chunk.to_sql(table_name, conn, if_exists='replace', index=False)
        
        # 변경 사항 저장
        conn.commit()
        print(f"CSV 파일을 SQLite 데이터베이스 '{table_name}' 테이블로 변환 완료")
    
    except Exception as e:
        print(f"오류 발생: {e}")
    
    finally:
        # 연결 종료
        conn.close()


# # 함수 사용 예시
# csv_to_sqlite('your_data.csv', 'mydatabase.db', 'review')

# %% [markdown]
# ## Review table

# %%
reveiw_csv = f'csv/sample_review.csv'

# %%
# reveiw table 추가
csv_to_sqlite(reveiw_csv, 'ASAC_MAP.db', 'review')
# Out:
# CSV 파일을 SQLite 데이터베이스 'review' 테이블로 변환 완료

# %% [markdown]
# ## Business table

# %%
dusiness_csv = pd.read_csv('csv/sample_business_final.csv')

# %%
dusiness_csv.head()
# Out:
#    Unnamed: 0  business_id                                               name  \
# 0       13368       110650                                       M Restaurant
# 1       17740       110907                                    Baker Boss Cafe
# 2        2010        28638  Embassy Suites by Hilton Tampa Downtown Conven...
# 3       51937       100086                                            Chili's
# 4       10484       136473                   The Blind Tiger Cafe - Westchase
#
#                  address          city state postal_code   latitude  \
# 0           231 S 8th St  Philadelphia    PA       19106  39.947326
# 1  5694 Nolensville Pike     Nashville    TN       37211  36.046953
# 2      513 S Florida Ave         Tampa    FL       33602  27.942315
# 3    1741 Manhattan Blvd        Harvey    LA       70058  29.888604
# 4      10118 Montague St         Tampa    FL       33626  28.044055
#
#    longitude  is_open  attributes                                   category  \
# 0 -75.154311        0         NaN                       ['Food', 'Desserts']
# 1 -86.710437        1         NaN              ['Restaurants', 'Vietnamese']
# 2 -82.454761        1         NaN                   ['Restaurants', 'Cafes']
# 3 -90.055884        1         NaN  ['Restaurants', 'American (Traditional)']
# 4 -82.597213        1         NaN              ['Restaurants', 'Sandwiches']
#
#                 region  review_count_biz  average_stars_biz  bined_stars  \
# 0  Philadelphia, 19106              51.0           3.705882          3.5
# 1     Nashville, 37211              59.0           4.406780          4.5
# 2         Tampa, 33602             108.0           2.212963          2.0
# 3        Harvey, 70058              88.0           1.863636          2.0
# 4         Tampa, 33626              99.0           3.787879          4.0
#
#   review_count_bin
# 0     (45.0, 65.0]
# 1     (45.0, 65.0]
# 2   (105.0, 125.0]
# 3    (85.0, 105.0]
# 4    (85.0, 105.0]

# %%
dusiness_csv = dusiness_csv.drop(columns=['Unnamed: 0'])

# %%
dusiness_csv = f'csv/sample_business_final.csv'

# %%
csv_to_sqlite(dusiness_csv, 'ASAC_MAP.db', 'business')
# Out:
# CSV 파일을 SQLite 데이터베이스 'business' 테이블로 변환 완료

# %% [markdown]
# ## User table

# %%
user_csv = f'csv/sample_user_df.csv'

# %%
csv_to_sqlite(user_csv, 'ASAC_MAP.db', 'user')
# Out:
# CSV 파일을 SQLite 데이터베이스 'user' 테이블로 변환 완료

# %% [markdown]
# ## table 조회

# %%
import sqlite3

# 데이터베이스 파일에 연결
conn = sqlite3.connect('ASAC_MAP.db')
cursor = conn.cursor()

# 테이블 조회 쿼리 실행
cursor.execute("SELECT * FROM business LIMIT 10")

# 결과를 가져옴
rows = cursor.fetchall()

# 결과 출력
for row in rows:
    print(row)
# Out:
# (13368, 110650, 'M Restaurant', '231 S 8th St', 'Philadelphia', 'PA', '19106', 39.9473257341, -75.1543113996, 0, None, "['Food', 'Desserts']", 'Philadelphia, 19106', 51.0, 3.7058823529411766, 3.5, '(45.0, 65.0]')
# (17740, 110907, 'Baker Boss Cafe', '5694 Nolensville Pike', 'Nashville', 'TN', '37211', 36.0469533703, -86.7104372755, 1, None, "['Restaurants', 'Vietnamese']", 'Nashville, 37211', 59.0, 4.406779661016949, 4.5, '(45.0, 65.0]')
# (2010, 28638, 'Embassy Suites by Hilton Tampa Downtown Convention Center', '513 S Florida Ave', 'Tampa', 'FL', '33602', 27.9423153, -82.4547605, 1, None, "['Restaurants', 'Cafes']", 'Tampa, 33602', 108.0, 2.212962962962963, 2.0, '(105.0, 125.0]')
# (51937, 100086, "Chili's", '1741 Manhattan Blvd', 'Harvey', 'LA', '70058', 29.8886043, -90.0558844, 1, None, "['Restaurants', 'American (Traditional)']", 'Harvey, 70058', 88.0, 1.8636363636363635, 2.0, '(85.0, 105.0]')
# (10484, 136473, 'The Blind Tiger Cafe - Westchase', '10118 Montague St', 'Tampa', 'FL', '33626', 28.0440549, -82.597213, 1, None, "['Restaurants', 'Sandwiches']", 'Tampa, 33626', 99.0, 3.787878787878788, 4.0, '(85.0, 105.0]')
# (30202, 87483, 'Sonic Drive-In', '3655 N Mount Juliet Rd', 'Mount Juliet', 'TN', '37122', 36.2213793, -86.5145423, 1, None, "['Food', 'Ice Cream & Frozen Yogurt']", 'Mount Juliet, 37122', 34.0, 1.1764705882352942, 1.0, '(25.0, 45.0]')
# (9628, 40372, 'The Breakfast Grille', '8536 Ridge Rd', 'New Port Richey', 'FL', '34654', 28.2797993, -82.6734224, 1, None, "['Restaurants', 'Mediterranean']", 'New Port Richey, 34654', 32.0, 4.09375, 4.0, '(25.0, 45.0]')
# (19833, 25856, 'Chapala Mexican Restaurant', '5697 N Glenwood St', 'Garden City', 'ID', '83714', 43.6568282, -116.2801126, 0, None, "['Restaurants', 'Mexican']", 'Garden City, 83714', 29.0, 3.0689655172413794, 3.0, '(25.0, 45.0]')
# (60613, 123142, 'Pomodoro Pizza & Italian Restaurant', '200 Chestnut St', 'Downingtown', 'PA', '19335', 40.0076775, -75.6956453, 1, None, "['Restaurants', 'Pizza']", 'Downingtown, 19335', 150.0, 4.42, 4.5, '(145.0, 165.0]')
# (1370, 40347, 'Nicoletto’s Italian Kitchen', '2123 Belcourt Ave', 'Nashville', 'TN', '37212', 36.1368318853, -86.8029680469, 1, None, "['Restaurants', 'Italian']", 'Nashville, 37212', 37.0, 4.216216216216216, 4.0, '(25.0, 45.0]')

# %%
# 모든 테이블 이름 조회
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# 테이블 이름 출력
for table in tables:
    print(table[0])
# Out:
# review
# business
# user

# %%
# 연결 종료
conn.close()
